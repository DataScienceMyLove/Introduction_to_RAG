# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
key = os.getenv("OPENAI_API_KEY")

if key is None:
    print("Clé introuvable")
else:
    print(f"Clé trouvée, longueur = {len(key)}")
# Out:
# Clé trouvée, longueur = 164

# %%
from openai import OpenAI
openai_client = OpenAI()
